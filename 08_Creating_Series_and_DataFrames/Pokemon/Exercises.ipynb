# %% [markdown]
# # Pokemon

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Create a data dictionary that looks like the DataFrame below

# %%
raw_data = {'evolution': ['Ivysaur', 'Charmeleon', 'Wartortle', 'Metapod'],
           'hp': [45,39,44,45],
           'name': ['Bulbasaur', 'Charmander', 'Squirtle', 'Caterpie'],
           'pokedex': ['yes', 'no', 'yes', 'no'],
           'type': ['grass', 'fire', 'water', 'bug']}

# %%
# Out:
#     evolution  hp        name pokedex   type
# 0     Ivysaur  45   Bulbasaur     yes  grass
# 1  Charmeleon  39  Charmander      no   fire
# 2   Wartortle  44    Squirtle     yes  water
# 3     Metapod  45    Caterpie      no    bug

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
df = pd.DataFrame(raw_data)
df
# Out:
#     evolution  hp        name pokedex   type
# 0     Ivysaur  45   Bulbasaur     yes  grass
# 1  Charmeleon  39  Charmander      no   fire
# 2   Wartortle  44    Squirtle     yes  water
# 3     Metapod  45    Caterpie      no    bug

# %% [markdown]
# ### Step 4. Ops...it seems the DataFrame columns are in alphabetical order. Place  the order of the columns as name, type, hp, evolution, pokedex

# %%
df = df[['name', 'type', 'hp', 'evolution', 'pokedex']]
df
# Out:
#          name   type  hp   evolution pokedex
# 0   Bulbasaur  grass  45     Ivysaur     yes
# 1  Charmander   fire  39  Charmeleon      no
# 2    Squirtle  water  44   Wartortle     yes
# 3    Caterpie    bug  45     Metapod      no

# %% [markdown]
# ### Step 5. Add another column called place, and insert what you have in mind.

# %%
df.insert(4,'place', ['Paris', 'Evreux', 'La Courneuve', 'Cergy'])
df
# Out:
#          name   type  hp   evolution         place pokedex
# 0   Bulbasaur  grass  45     Ivysaur         Paris     yes
# 1  Charmander   fire  39  Charmeleon        Evreux      no
# 2    Squirtle  water  44   Wartortle  La Courneuve     yes
# 3    Caterpie    bug  45     Metapod         Cergy      no

# %% [markdown]
# ### Step 6. Present the type of each column

# %%
print(df.dtypes, '\n'+'*'*20 )
print(df.info())
# Out:
# name         object
# type         object
# hp            int64
# evolution    object
# place        object
# pokedex      object
# dtype: object
# ********************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
# name         4 non-null object
# type         4 non-null object
# hp           4 non-null int64
# evolution    4 non-null object
# place        4 non-null object
# pokedex      4 non-null object
# dtypes: int64(1), object(5)
# memory usage: 272.0+ bytes
# None

# %% [markdown]
# ### BONUS: Create your own question and answer it.
